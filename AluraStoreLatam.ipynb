# %% [markdown]
# <a href="https://colab.research.google.com/github/Luciajantus/Alura-Store_latam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos_tienda = tienda["Precio"].sum()
ingresos_tienda2 = tienda2["Precio"].sum()
ingresos_tienda3 = tienda3["Precio"].sum()
ingresos_tienda4 = tienda4["Precio"].sum()
print(f"Ingresos tienda 1: {ingresos_tienda}")
print(f"Ingresos tienda 2: {ingresos_tienda2}")
print(f"Ingresos tienda 3: {ingresos_tienda3}")
print(f"Ingresos tienda 4: {ingresos_tienda4}")
# Out:
# Ingresos tienda 1: 1150880400.0
# Ingresos tienda 2: 1116343500.0
# Ingresos tienda 3: 1098019600.0
# Ingresos tienda 4: 1038375700.0

# %% [markdown]
# # 2. Calificación promedio de la tienda

# %%
calificacion_tienda = tienda["Calificación"].mean()
calificacion_tienda2 = tienda2["Calificación"].mean()
calificacion_tienda3 = tienda3["Calificación"].mean()
calificacion_tienda4 = tienda4["Calificación"].mean()
print(f"Calificación tienda 1: {calificacion_tienda}")
print(f"Calificación tienda 2: {calificacion_tienda2}")
print(f"Calificación tienda 3: {calificacion_tienda3}")
print(f"Calificación tienda 4: {calificacion_tienda4}")
# Out:
# Calificación tienda 1: 3.976685036032217
# Calificación tienda 2: 4.037303942348453
# Calificación tienda 3: 4.048325561678677
# Calificación tienda 4: 3.9957591178965224

# %%
tiendas_nombres = ["Tienda", "Tienda 2", "Tienda 3", "Tienda 4"]
ingresos = [ingresos_tienda, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4]
calificaciones = [calificacion_tienda, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]
envios = [envio_t1, envio_t2, envio_t3, envio_t4]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Ventas por categoría

# %%
mis_tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

print("Resumen de Ventas por Categoría:")

for i, t in enumerate(mis_tiendas):
    print(f"\n{nombres_tiendas[i]}:")
    # Agrupamos y contamos las categorías
    print(t['Categoría del Producto'].value_counts())
# Out:
# Resumen de Ventas por Categoría:
#
# Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
for i, t in enumerate(mis_tiendas):
    conteo_productos = t['Producto'].value_counts()

    # Identificación técnica
    top_producto = conteo_productos.idxmax()
    top_ventas = conteo_productos.max()
    peor_producto = conteo_productos.idxmin()
    peor_ventas = conteo_productos.min()

    print(f"\n--- Análisis de Inventario: {nombres_tiendas[i]} ---")
    print(f"Estrella: {top_producto} con {top_ventas} ventas.")
    print(f"Producto estancado: {peor_producto} con {peor_ventas} ventas.")
# Out:
# --- Análisis de Inventario: Tienda 1 ---
# Estrella: Microondas con 60 ventas.
# Producto estancado: Auriculares con micrófono con 33 ventas.
#
# --- Análisis de Inventario: Tienda 2 ---
# Estrella: Iniciando en programación con 65 ventas.
# Producto estancado: Juego de mesa con 32 ventas.
#
# --- Análisis de Inventario: Tienda 3 ---
# Estrella: Kit de bancas con 57 ventas.
# Producto estancado: Bloques de construcción con 35 ventas.
#
# --- Análisis de Inventario: Tienda 4 ---
# Estrella: Cama box con 62 ventas.
# Producto estancado: Guitarra eléctrica con 33 ventas.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_t1 = tienda["Costo de envío"].mean()
envio_t2 = tienda2["Costo de envío"].mean()
envio_t3 = tienda3["Costo de envío"].mean()
envio_t4 = tienda4["Costo de envío"].mean()
print(f"Envío tienda 1: {envio_t1}")
print(f"Envío tienda 2: {envio_t2}")
print(f"Envío tienda 3: {envio_t3}")
print(f"Envío tienda 4: {envio_t4}")
# Out:
# Envío tienda 1: 26018.60958033065
# Envío tienda 2: 25216.235693090293
# Envío tienda 3: 24805.680373039424
# Envío tienda 4: 23459.457167090754

# %%
import matplotlib.pyplot as plt

# 1. Visualización: Calificación Promedio
plt.figure(figsize=(10, 5))
plt.plot(nombres, ratings, marker='o', linestyle='-', color='orange')
plt.title('Nivel de Satisfacción (Calificación Promedio)')
plt.ylim(0, 5)
plt.grid(True)
plt.show()

# %%
plt.bar(df_resumen['Tiendas'], df_resumen['Ingresos'])
plt.title('Nivel de Ingresos')
# Out:
# Text(0.5, 1.0, 'Nivel de Ingresos')

# %%
envios_promedio = [t['Costo de envío'].mean() for t in mis_tiendas]

plt.figure(figsize=(10, 6))
plt.bar(nombres_tiendas, envios_promedio, color='lightcoral')


plt.title('Costo de Envío Promedio por Tienda')
plt.ylabel('Costo en Pesos ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

for i, envio in enumerate(envios_promedio):
    print(f"{nombres_tiendas[i]}: ${envio:.2f}")
# Out:
# Tienda 1: $26018.61
# Tienda 2: $25216.24
# Tienda 3: $24805.68
# Tienda 4: $23459.46

# %% [markdown]
# ## **Informe**

# %% [markdown]
# ### **Desarrollo y análisis**

# %% [markdown]
# #### Tras procesar la información de las cuatro tiendas, hemos identificado los siguientes puntos clave:
#
# Facturación: La Tienda 4 presenta el rendimiento financiero más pobre, con ingresos totales de aproximadamente $1,038 millones, la cifra más baja de toda la cadena.
#
# Gestión de Inventario: Aunque la categoría líder en la Tienda 4 es Muebles (con 442 unidades vendidas), el volumen de ventas es insuficiente para compensar sus costos operativos comparado con el éxito de categorías más dinámicas en otras sucursales.
#
# Satisfacción del Cliente: La reputación de la Tienda 4 es crítica, con una calificación promedio de 3.99 estrellas, situándose en el rango más bajo de la empresa junto a la Tienda 1.
#
# Eficiencia Logística: Los costos de envío en la Tienda 4 son superiores al promedio, lo que erosiona el margen de ganancia de cada venta realizada.

# %% [markdown]
# ### **Conclusión y Recomendación**

# %% [markdown]
# #### Basado en la evidencia técnica recopilada, la recomendación final es proceder con la venta de la Tienda 4.
